# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import numpy as np

# %%
# Load the dataset
file_path = '../dataset/credit_train.csv'
df = pd.read_csv(file_path)

# %%
# Fix column data types
for col in df.select_dtypes(include=['object']).columns:
    try:
        # Attempt to convert numeric-looking strings to floats
        df[col] = pd.to_numeric(df[col], errors='ignore')
    except Exception as e:
        print(f"Error converting column {col}: {e}")
# Out:
# /tmp/ipykernel_942660/3883513807.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')

# %%
# Validate numerical columns
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    invalid_values = df[col][~df[col].apply(lambda x: np.isfinite(x))]
    if not invalid_values.empty:
        print(f"Invalid values found in {col}: {invalid_values}")
        df[col] = df[col].replace([np.inf, -np.inf], np.nan).fillna(df[col].median())
# Out:
# Invalid values found in Current Loan Amount: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Current Loan Amount, Length: 514, dtype: float64
# Invalid values found in Credit Score: 1        NaN
# 4        NaN
# 7        NaN
# 11       NaN
# 15       NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Credit Score, Length: 19668, dtype: float64
# Invalid values found in Annual Income: 1        NaN
# 4        NaN
# 7        NaN
# 11       NaN
# 15       NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Annual Income, Length: 19668, dtype: float64
# Invalid values found in Monthly Debt: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Monthly Debt, Length: 514, dtype: float64
# Invalid values found in Years of Credit History: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Years of Credit History, Length: 514, dtype: float64
# Invalid values found in Months since last delinquent: 0        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 9        NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Months since last delinquent, Length: 53655, dtype: float64
# Invalid values found in Number of Open Accounts: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Number of Open Accounts, Length: 514, dtype: float64
# Invalid values found in Number of Credit Problems: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Number of Credit Problems, Length: 514, dtype: float64
# Invalid values found in Current Credit Balance: 100000   NaN
# 100001   NaN
# 100002   NaN
# 100003   NaN
# 100004   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Current Credit Balance, Length: 514, dtype: float64
# Invalid values found in Maximum Open Credit: 30180    NaN
# 98710    NaN
# 100000   NaN
# 100001   NaN
# 100002   NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Maximum Open Credit, Length: 516, dtype: float64
# Invalid values found in Bankruptcies: 905      NaN
# 1699     NaN
# 1995     NaN
# 3462     NaN
# 4587     NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Bankruptcies, Length: 718, dtype: float64
# Invalid values found in Tax Liens: 9632     NaN
# 10546    NaN
# 19274    NaN
# 20727    NaN
# 28595    NaN
#           ..
# 100509   NaN
# 100510   NaN
# 100511   NaN
# 100512   NaN
# 100513   NaN
# Name: Tax Liens, Length: 524, dtype: float64

# %%
# Handle missing values
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col] = df[col].fillna(df[col].median())
print("\nMissing values handled by filling with median.")
# Out:
# Missing values handled by filling with median.

# %%
# Handle categorical columns
for col in df.select_dtypes(include=['object', 'category']).columns:
    df[col] = df[col].fillna('Unknown')
    df[col] = df[col].astype('category')
print("\nCategorical columns handled by filling with 'Unknown'.")
# Out:
# Categorical columns handled by filling with 'Unknown'.

# %%
# Drop duplicate rows
df = df.drop_duplicates()
print("\nDuplicate rows dropped.")
# Out:
# Duplicate rows dropped.

# %%
# Drop unnecessary columns
if 'Loan ID' in df.columns and 'Customer ID' in df.columns:
    df = df.drop(columns=['Loan ID', 'Customer ID'])
    print("\nColumns 'Loan ID' and 'Customer ID' dropped.")
# Out:
# Columns 'Loan ID' and 'Customer ID' dropped.

# %%
# Handle outliers using IQR
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
print("\nOutliers handled using IQR method.")
# Out:
# Outliers handled using IQR method.

# %%
# Select relevant features for clustering
selected_features = [
    'Current Loan Amount', 'Credit Score', 'Annual Income',
    'Monthly Debt', 'Years of Credit History',
    'Number of Open Accounts', 'Current Credit Balance', 'Maximum Open Credit'
]
df_selected = df[selected_features]

# %%
# Standardize the selected features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_selected)

# %%
# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
pca_df = pd.DataFrame(data=principal_components, columns=["PC1", "PC2"])
print(f"\nExplained Variance Ratio: {pca.explained_variance_ratio_}")
# Out:
# Explained Variance Ratio: [0.39007166 0.14359364]

# %%
# Perform clustering using KMeans
kmeans = KMeans(n_clusters=5, random_state=42)
pca_df['Cluster'] = kmeans.fit_predict(pca_df)

# %%
# Calculate silhouette score
score = silhouette_score(pca_df.iloc[:, :-1], pca_df['Cluster'])
print(f"Silhouette Score: {score}")
# Out:
# Silhouette Score: 0.3244739176703358

# %%
# Visualize clusters
plt.figure(figsize=(10, 7))
sns.scatterplot(x="PC1", y="PC2", hue="Cluster", data=pca_df, palette='viridis')
plt.title("Clusters Visualization")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Cluster")
plt.show()

# %%
# Display information about each cluster from raw data
raw_data = df.reset_index(drop=True)
raw_data['Cluster'] = pca_df['Cluster'].values

# %%
# Assign cluster labels to raw data and analyze clusters
for cluster_label in sorted(raw_data['Cluster'].unique()):
    cluster_data = raw_data[raw_data['Cluster'] == cluster_label]
    print(f"\nCluster {cluster_label} Characteristics:")
    print(cluster_data.describe(include='all'))
# Out:
# Cluster 0 Characteristics:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# count         6102          6102.000000        6102   6102.000000
# unique           3                  NaN           3           NaN
# top     Fully Paid                  NaN  Short Term           NaN
# freq          4315                  NaN        3951           NaN
# mean           NaN        323098.049820         NaN    717.034743
# std            NaN        139384.333237         NaN     12.710439
# min            NaN         21604.000000         NaN    681.000000
# 25%            NaN        222266.000000         NaN    710.000000
# 50%            NaN        322003.000000         NaN    724.000000
# 75%            NaN        407561.000000         NaN    724.000000
# max            NaN        788480.000000         NaN    750.000000
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# count    6.102000e+03                 6102           6102                6102
# unique            NaN                   12              5                  16
# top               NaN            10+ years           Rent  Debt Consolidation
# freq              NaN                 1462           3079                5095
# mean     1.144154e+06                  NaN            NaN                 NaN
# std      2.570203e+05                  NaN            NaN                 NaN
# min      3.309230e+05                  NaN            NaN                 NaN
# 25%      1.011123e+06                  NaN            NaN                 NaN
# 50%      1.174162e+06                  NaN            NaN                 NaN
# 75%      1.174162e+06                  NaN            NaN                 NaN
# max      2.114662e+06                  NaN            NaN                 NaN
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count    6102.000000              6102.000000                        6102.0
# unique           NaN                      NaN                           NaN
# top              NaN                      NaN                           NaN
# freq             NaN                      NaN                           NaN
# mean    17559.463374                14.006981                          32.0
# std      6459.551781                 4.239744                           0.0
# min       617.500000                 3.600000                          32.0
# 25%     13052.335000                10.900000                          32.0
# 50%     17016.400000                13.800000                          32.0
# 75%     21537.640000                16.600000                          32.0
# max     40945.760000                33.400000                          32.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# count               6102.000000                     6102.0
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                  10.845624                        0.0
# std                    3.718028                        0.0
# min                    2.000000                        0.0
# 25%                    8.000000                        0.0
# 50%                   10.000000                        0.0
# 75%                   13.000000                        0.0
# max                   22.000000                        0.0
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# count              6102.000000         6.102000e+03        6102.0     6102.0
# unique                     NaN                  NaN           NaN        NaN
# top                        NaN                  NaN           NaN        NaN
# freq                       NaN                  NaN           NaN        NaN
# mean             249669.042281         4.863344e+05           0.0        0.0
# std              106884.483002         1.886103e+05           0.0        0.0
# min                   0.000000         0.000000e+00           0.0        0.0
# 25%              175436.500000         3.539855e+05           0.0        0.0
# 50%              245328.000000         4.666310e+05           0.0        0.0
# 75%              318554.000000         5.928010e+05           0.0        0.0
# max              722399.000000         1.464100e+06           0.0        0.0
#
#         Cluster
# count    6102.0
# unique      NaN
# top         NaN
# freq        NaN
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
#
# Cluster 1 Characteristics:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# count         5552          5552.000000        5552   5552.000000
# unique           2                  NaN           2           NaN
# top     Fully Paid                  NaN  Short Term           NaN
# freq          4037                  NaN        4903           NaN
# mean           NaN        168399.844020         NaN    718.531160
# std            NaN         88917.425657         NaN     13.217296
# min            NaN         15422.000000         NaN    681.000000
# 25%            NaN        107668.000000         NaN    711.000000
# 50%            NaN        156574.000000         NaN    724.000000
# 75%            NaN        219186.000000         NaN    724.000000
# max            NaN        769164.000000         NaN    750.000000
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# count    5.552000e+03                 5552           5552                5552
# unique            NaN                   12              4                  15
# top               NaN              2 years           Rent  Debt Consolidation
# freq              NaN                  805           3852                3939
# mean     8.692416e+05                  NaN            NaN                 NaN
# std      3.074969e+05                  NaN            NaN                 NaN
# min      2.722890e+05                  NaN            NaN                 NaN
# 25%      5.998062e+05                  NaN            NaN                 NaN
# 50%      8.524920e+05                  NaN            NaN                 NaN
# 75%      1.174162e+06                  NaN            NaN                 NaN
# max      2.086637e+06                  NaN            NaN                 NaN
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count    5552.000000              5552.000000                        5552.0
# unique           NaN                      NaN                           NaN
# top              NaN                      NaN                           NaN
# freq             NaN                      NaN                           NaN
# mean     8553.798734                11.137950                          32.0
# std      4796.836028                 3.624406                           0.0
# min         0.000000                 3.700000                          32.0
# 25%      4808.425000                 8.700000                          32.0
# 50%      8134.280000                10.500000                          32.0
# 75%     11595.272500                13.200000                          32.0
# max     29435.560000                32.600000                          32.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# count               5552.000000                     5552.0
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                   7.184618                        0.0
# std                    3.045555                        0.0
# min                    0.000000                        0.0
# 25%                    5.000000                        0.0
# 50%                    7.000000                        0.0
# 75%                    9.000000                        0.0
# max                   22.000000                        0.0
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# count              5552.000000          5552.000000        5552.0     5552.0
# unique                     NaN                  NaN           NaN        NaN
# top                        NaN                  NaN           NaN        NaN
# freq                       NaN                  NaN           NaN        NaN
# mean             109009.947046        230125.381124           0.0        0.0
# std               64352.432915        124671.322041           0.0        0.0
# min                   0.000000             0.000000           0.0        0.0
# 25%               62828.250000        141922.000000           0.0        0.0
# 50%              103483.500000        216667.000000           0.0        0.0
# 75%              150693.750000        300289.000000           0.0        0.0
# max              384978.000000        871376.000000           0.0        0.0
#
#         Cluster
# count    5552.0
# unique      NaN
# top         NaN
# freq        NaN
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# Cluster 2 Characteristics:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# count         4686          4686.000000        4686   4686.000000
# unique           2                  NaN           2           NaN
# top     Fully Paid                  NaN  Short Term           NaN
# freq          3787                  NaN        3867           NaN
# mean           NaN        304066.535211         NaN    736.341229
# std            NaN        134891.358036         NaN      9.993652
# min            NaN         21472.000000         NaN    704.000000
# 25%            NaN        214929.000000         NaN    724.000000
# 50%            NaN        296395.000000         NaN    739.000000
# 75%            NaN        398480.500000         NaN    745.000000
# max            NaN        780868.000000         NaN    751.000000
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# count    4.686000e+03                 4686           4686                4686
# unique            NaN                   12              4                  14
# top               NaN            10+ years  Home Mortgage  Debt Consolidation
# freq              NaN                 1612           2632                3941
# mean     1.243689e+06                  NaN            NaN                 NaN
# std      3.083435e+05                  NaN            NaN                 NaN
# min      3.440900e+05                  NaN            NaN                 NaN
# 25%      1.066950e+06                  NaN            NaN                 NaN
# 50%      1.174162e+06                  NaN            NaN                 NaN
# 75%      1.413101e+06                  NaN            NaN                 NaN
# max      2.114890e+06                  NaN            NaN                 NaN
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count    4686.000000              4686.000000                        4686.0
# unique           NaN                      NaN                           NaN
# top              NaN                      NaN                           NaN
# freq             NaN                      NaN                           NaN
# mean    17546.189334                20.135851                          32.0
# std      6597.222707                 5.584507                           0.0
# min       280.630000                 5.500000                          32.0
# 25%     12903.327500                15.900000                          32.0
# 50%     17153.865000                19.400000                          32.0
# 75%     21833.517500                23.700000                          32.0
# max     40775.710000                33.600000                          32.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# count               4686.000000                     4686.0
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                  11.383269                        0.0
# std                    3.746208                        0.0
# min                    2.000000                        0.0
# 25%                    9.000000                        0.0
# 50%                   11.000000                        0.0
# 75%                   14.000000                        0.0
# max                   22.000000                        0.0
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# count              4686.000000         4.686000e+03        4686.0     4686.0
# unique                     NaN                  NaN           NaN        NaN
# top                        NaN                  NaN           NaN        NaN
# freq                       NaN                  NaN           NaN        NaN
# mean             332784.144473         7.911986e+05           0.0        0.0
# std              137576.730357         2.675226e+05           0.0        0.0
# min                   0.000000         0.000000e+00           0.0        0.0
# 25%              239951.000000         5.933895e+05           0.0        0.0
# 50%              328139.500000         7.618490e+05           0.0        0.0
# 75%              423206.000000         9.625165e+05           0.0        0.0
# max              749968.000000         1.472372e+06           0.0        0.0
#
#         Cluster
# count    4686.0
# unique      NaN
# top         NaN
# freq        NaN
# mean        2.0
# std         0.0
# min         2.0
# 25%         2.0
# 50%         2.0
# 75%         2.0
# max         2.0
#
# Cluster 3 Characteristics:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# count         5733          5733.000000        5733   5733.000000
# unique           2                  NaN           2           NaN
# top     Fully Paid                  NaN  Short Term           NaN
# freq          4546                  NaN        5303           NaN
# mean           NaN        191316.259550         NaN    737.497296
# std            NaN         93771.861551         NaN      9.448572
# min            NaN         21472.000000         NaN    699.000000
# 25%            NaN        123574.000000         NaN    729.000000
# 50%            NaN        180048.000000         NaN    740.000000
# 75%            NaN        241912.000000         NaN    746.000000
# max            NaN        671418.000000         NaN    751.000000
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# count    5.733000e+03                 5733           5733                5733
# unique            NaN                   12              4                  16
# top               NaN            10+ years           Rent  Debt Consolidation
# freq              NaN                 1278           3055                4295
# mean     9.594634e+05                  NaN            NaN                 NaN
# std      3.155072e+05                  NaN            NaN                 NaN
# min      2.721750e+05                  NaN            NaN                 NaN
# 25%      7.189600e+05                  NaN            NaN                 NaN
# 50%      9.484800e+05                  NaN            NaN                 NaN
# 75%      1.174162e+06                  NaN            NaN                 NaN
# max      2.106074e+06                  NaN            NaN                 NaN
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count    5733.000000              5733.000000                        5733.0
# unique           NaN                      NaN                           NaN
# top              NaN                      NaN                           NaN
# freq             NaN                      NaN                           NaN
# mean    10017.753016                16.695726                          32.0
# std      5204.969183                 5.185835                           0.0
# min         0.000000                 4.400000                          32.0
# 25%      6114.200000                12.900000                          32.0
# 50%      9493.160000                16.000000                          32.0
# 75%     13341.800000                19.600000                          32.0
# max     36528.070000                33.500000                          32.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# count               5733.000000                     5733.0
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                   8.390720                        0.0
# std                    3.220843                        0.0
# min                    1.000000                        0.0
# 25%                    6.000000                        0.0
# 50%                    8.000000                        0.0
# 75%                   10.000000                        0.0
# max                   22.000000                        0.0
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# count              5733.000000         5.733000e+03        5733.0     5733.0
# unique                     NaN                  NaN           NaN        NaN
# top                        NaN                  NaN           NaN        NaN
# freq                       NaN                  NaN           NaN        NaN
# mean             157068.383394         4.203620e+05           0.0        0.0
# std               91863.675016         2.162453e+05           0.0        0.0
# min                   0.000000         0.000000e+00           0.0        0.0
# 25%               90573.000000         2.700940e+05           0.0        0.0
# 50%              152551.000000         3.852420e+05           0.0        0.0
# 75%              215840.000000         5.375260e+05           0.0        0.0
# max              560519.000000         1.471668e+06           0.0        0.0
#
#         Cluster
# count    5733.0
# unique      NaN
# top         NaN
# freq        NaN
# mean        3.0
# std         0.0
# min         3.0
# 25%         3.0
# 50%         3.0
# 75%         3.0
# max         3.0
#
# Cluster 4 Characteristics:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# count         3443          3443.000000        3443   3443.000000
# unique           2                  NaN           2           NaN
# top     Fully Paid                  NaN  Short Term           NaN
# freq          2511                  NaN        1843           NaN
# mean           NaN        492090.587859         NaN    720.792042
# std            NaN        162186.483521         NaN     14.513564
# min            NaN         22396.000000         NaN    681.000000
# 25%            NaN        394790.000000         NaN    715.000000
# 50%            NaN        495462.000000         NaN    724.000000
# 75%            NaN        606804.000000         NaN    725.000000
# max            NaN        789250.000000         NaN    751.000000
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# count    3.443000e+03                 3443           3443                3443
# unique            NaN                   12              4                  13
# top               NaN            10+ years  Home Mortgage  Debt Consolidation
# freq              NaN                 1387           2118                3155
# mean     1.390124e+06                  NaN            NaN                 NaN
# std      3.038394e+05                  NaN            NaN                 NaN
# min      6.560700e+05                  NaN            NaN                 NaN
# 25%      1.174162e+06                  NaN            NaN                 NaN
# 50%      1.242448e+06                  NaN            NaN                 NaN
# 75%      1.614516e+06                  NaN            NaN                 NaN
# max      2.113826e+06                  NaN            NaN                 NaN
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count    3443.000000              3443.000000                        3443.0
# unique           NaN                      NaN                           NaN
# top              NaN                      NaN                           NaN
# freq             NaN                      NaN                           NaN
# mean    26373.967049                18.532414                          32.0
# std      6911.306623                 5.259848                           0.0
# min      5827.110000                 5.300000                          32.0
# 25%     21244.945000                14.800000                          32.0
# 50%     26394.990000                17.700000                          32.0
# 75%     31429.990000                21.800000                          32.0
# max     41038.860000                33.600000                          32.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# count               3443.000000                     3443.0
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                  13.427244                        0.0
# std                    3.971080                        0.0
# min                    2.000000                        0.0
# 25%                   11.000000                        0.0
# 50%                   13.000000                        0.0
# 75%                   16.000000                        0.0
# max                   22.000000                        0.0
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# count              3443.000000         3.443000e+03        3443.0     3443.0
# unique                     NaN                  NaN           NaN        NaN
# top                        NaN                  NaN           NaN        NaN
# freq                       NaN                  NaN           NaN        NaN
# mean             484639.583503         9.104941e+05           0.0        0.0
# std              141143.126559         2.522643e+05           0.0        0.0
# min               12217.000000         0.000000e+00           0.0        0.0
# 25%              387923.000000         7.232720e+05           0.0        0.0
# 50%              486837.000000         8.935520e+05           0.0        0.0
# 75%              591954.500000         1.092531e+06           0.0        0.0
# max              750975.000000         1.473516e+06           0.0        0.0
#
#         Cluster
# count    3443.0
# unique      NaN
# top         NaN
# freq        NaN
# mean        4.0
# std         0.0
# min         4.0
# 25%         4.0
# 50%         4.0
# 75%         4.0
# max         4.0

# %%
# Save raw data with cluster labels to a new CSV file
raw_data.to_csv('../dataset/credit_train_with_clusters.csv', index=False)
print("\nCluster labels added to raw data and saved to 'credit_train_with_clusters.csv'.")
# Out:
# Cluster labels added to raw data and saved to 'credit_train_with_clusters.csv'.

# %%
# Visualize comparisons of clusters based on raw features
features_to_plot = selected_features
fig, axes = plt.subplots(len(features_to_plot), 3, figsize=(18, 6 * len(features_to_plot)))
for i, feature in enumerate(features_to_plot):
    # Boxplot
    sns.boxplot(x='Cluster', y=feature, data=raw_data, ax=axes[i, 0])
    axes[i, 0].set_title(f"Boxplot of {feature} Across Clusters")
    axes[i, 0].set_xlabel("Cluster")
    axes[i, 0].set_ylabel(feature)

    # Histogram
    for cluster_label in sorted(raw_data['Cluster'].unique()):
        sns.histplot(
            raw_data[raw_data['Cluster'] == cluster_label][feature],
            bins=20, kde=True, ax=axes[i, 1], label=f"Cluster {cluster_label}", alpha=0.5
        )
    axes[i, 1].set_title(f"Histogram of {feature} by Cluster")
    axes[i, 1].set_xlabel(feature)
    axes[i, 1].legend()

    # Pie chart
    cluster_counts = raw_data.groupby('Cluster')[feature].count()
    axes[i, 2].pie(
        cluster_counts,
        labels=[f"Cluster {label}" for label in cluster_counts.index],
        autopct='%1.1f%%', startangle=140,
    )
    axes[i, 2].set_title(f"Pie Chart of {feature} by Cluster")

plt.tight_layout()
plt.show()
